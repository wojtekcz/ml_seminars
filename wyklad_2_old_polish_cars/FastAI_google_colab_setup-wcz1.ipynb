# %%
#Setup Google Drive Integration

# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# !mkdir -p drive
# !google-drive-ocamlfuse drive -o nonempty
# Out:
# Preconfiguring packages ...
# Selecting previously unselected package cron.
# (Reading database ... 16712 files and directories currently installed.)
# Preparing to unpack .../00-cron_3.0pl1-128ubuntu5_amd64.deb ...
# Unpacking cron (3.0pl1-128ubuntu5) ...
# Selecting previously unselected package libapparmor1:amd64.
# Preparing to unpack .../01-libapparmor1_2.11.0-2ubuntu17.1_amd64.deb ...
# Unpacking libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Selecting previously unselected package libdbus-1-3:amd64.
# Preparing to unpack .../02-libdbus-1-3_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dbus.
# Preparing to unpack .../03-dbus_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking dbus (1.10.22-1ubuntu1) ...
# Selecting previously unselected package dirmngr.
# Preparing to unpack .../04-dirmngr_2.1.15-1ubuntu8_amd64.deb ...
# Unpacking dirmngr (2.1.15-1ubuntu8) ...
# Selecting previously unselected package distro-info-data.
# Preparing to unpack .../05-distro-info-data_0.36ubuntu0.1_all.deb ...
# Unpacking distro-info-data (0.36ubuntu0.1) ...
# Selecting previously unselected package libkmod2:amd64.
# Preparing to unpack .../06-libkmod2_24-1ubuntu2_amd64.deb ...
# Unpacking libkmod2:amd64 (24-1ubuntu2) ...
# Selecting previously unselected package kmod.
# Preparing to unpack .../07-kmod_24-1ubuntu2_amd64.deb ...
# Unpacking kmod (24-1ubuntu2) ...
# Selecting previously unselected package lsb-release.
# Preparing to unpack .../08-lsb-release_9.20160110ubuntu5_all.deb ...
# Unpacking lsb-release (9.20160110ubuntu5) ...
# Selecting previously unselected package libgirepository-1.0-1:amd64.
# Preparing to unpack .../09-libgirepository-1.0-1_1.54.1-1_amd64.deb ...
# Unpacking libgirepository-1.0-1:amd64 (1.54.1-1) ...
# Selecting previously unselected package gir1.2-glib-2.0:amd64.
# Preparing to unpack .../10-gir1.2-glib-2.0_1.54.1-1_amd64.deb ...
# Unpacking gir1.2-glib-2.0:amd64 (1.54.1-1) ...
# Selecting previously unselected package iso-codes.
# Preparing to unpack .../11-iso-codes_3.75-1_all.deb ...
# Unpacking iso-codes (3.75-1) ...
# Selecting previously unselected package libdbus-glib-1-2:amd64.
# Preparing to unpack .../12-libdbus-glib-1-2_0.108-2_amd64.deb ...
# Unpacking libdbus-glib-1-2:amd64 (0.108-2) ...
# Selecting previously unselected package python-apt-common.
# Preparing to unpack .../13-python-apt-common_1.4.0~beta3build2_all.deb ...
# Unpacking python-apt-common (1.4.0~beta3build2) ...
# Selecting previously unselected package python3-apt.
# Preparing to unpack .../14-python3-apt_1.4.0~beta3build2_amd64.deb ...
# Unpacking python3-apt (1.4.0~beta3build2) ...
# Selecting previously unselected package python3-dbus.
# Preparing to unpack .../15-python3-dbus_1.2.4-1build3_amd64.deb ...
# Unpacking python3-dbus (1.2.4-1build3) ...
# Selecting previously unselected package python3-gi.
# Preparing to unpack .../16-python3-gi_3.24.1-2build1_amd64.deb ...
# Unpacking python3-gi (3.24.1-2build1) ...
# Selecting previously unselected package module-init-tools.
# Preparing to unpack .../17-module-init-tools_24-1ubuntu2_all.deb ...
# Unpacking module-init-tools (24-1ubuntu2) ...
# Selecting previously unselected package python-apt.
# Preparing to unpack .../18-python-apt_1.4.0~beta3build2_amd64.deb ...
# Unpacking python-apt (1.4.0~beta3build2) ...
# Selecting previously unselected package python-pycurl.
# Preparing to unpack .../19-python-pycurl_7.43.0-2build2_amd64.deb ...
# Unpacking python-pycurl (7.43.0-2build2) ...
# Selecting previously unselected package python-software-properties.
# Preparing to unpack .../20-python-software-properties_0.96.24.17_all.deb ...
# Unpacking python-software-properties (0.96.24.17) ...
# Selecting previously unselected package python3-software-properties.
# Preparing to unpack .../21-python3-software-properties_0.96.24.17_all.deb ...
# Unpacking python3-software-properties (0.96.24.17) ...
# Selecting previously unselected package software-properties-common.
# Preparing to unpack .../22-software-properties-common_0.96.24.17_all.deb ...
# Unpacking software-properties-common (0.96.24.17) ...
# Selecting previously unselected package unattended-upgrades.
# Preparing to unpack .../23-unattended-upgrades_0.98ubuntu1.1_all.deb ...
# Unpacking unattended-upgrades (0.98ubuntu1.1) ...
# Setting up python-apt-common (1.4.0~beta3build2) ...
# Setting up python3-apt (1.4.0~beta3build2) ...
# Setting up iso-codes (3.75-1) ...
# Setting up distro-info-data (0.36ubuntu0.1) ...
# Setting up python-pycurl (7.43.0-2build2) ...
# Setting up lsb-release (9.20160110ubuntu5) ...
# Setting up libgirepository-1.0-1:amd64 (1.54.1-1) ...
# Setting up libkmod2:amd64 (24-1ubuntu2) ...
# Setting up gir1.2-glib-2.0:amd64 (1.54.1-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Setting up unattended-upgrades (0.98ubuntu1.1) ...
#
# Creating config file /etc/apt/apt.conf.d/20auto-upgrades with new version
# Creating config file /etc/apt/apt.conf.d/50unattended-upgrades with new version
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up dirmngr (2.1.15-1ubuntu8) ...
# Setting up cron (3.0pl1-128ubuntu5) ...
# Adding group `crontab' (GID 102) ...
# Done.
# update-rc.d: warning: start and stop actions are no longer supported; falling back to defaults
# update-rc.d: warning: stop runlevel arguments (1) do not match cron Default-Stop values (none)
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Setting up kmod (24-1ubuntu2) ...
# Setting up libdbus-glib-1-2:amd64 (0.108-2) ...
# Setting up python3-gi (3.24.1-2build1) ...
# Setting up module-init-tools (24-1ubuntu2) ...
# Setting up python3-software-properties (0.96.24.17) ...
# Setting up dbus (1.10.22-1ubuntu1) ...
# Setting up python-apt (1.4.0~beta3build2) ...
# Setting up python3-dbus (1.2.4-1build3) ...
# Setting up python-software-properties (0.96.24.17) ...
# Setting up software-properties-common (0.96.24.17) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Processing triggers for dbus (1.10.22-1ubuntu1) ...
# gpg: keybox '/tmp/tmp6ozn8p0_/pubring.gpg' created
# gpg: /tmp/tmp6ozn8p0_/trustdb.gpg: trustdb created
# gpg: key AD5F235DF639B041: public key "Launchpad PPA for Alessandro Strada" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# Selecting previously unselected package libfuse2:amd64.
# (Reading database ... 18120 files and directories currently installed.)
# Preparing to unpack .../libfuse2_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Selecting previously unselected package fuse.
# Preparing to unpack .../fuse_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking fuse (2.9.7-1ubuntu1) ...
# Selecting previously unselected package google-drive-ocamlfuse.
# Preparing to unpack .../google-drive-ocamlfuse_0.6.21-0ubuntu2_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.6.21-0ubuntu2) ...
# Setting up libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up fuse (2.9.7-1ubuntu1) ...
# Setting up google-drive-ocamlfuse (0.6.21-0ubuntu2) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
#Fast.AI Setup
# !git clone https://github.com/fastai/fastai.git
import os
os.chdir("fastai")
# !git pull
# Out:
# Cloning into 'fastai'...
# remote: Counting objects: 3967, done.
# remote: Total 3967 (delta 0), reused 0 (delta 0), pack-reused 3966
# Receiving objects: 100% (3967/3967), 171.46 MiB | 43.42 MiB/s, done.
# Resolving deltas: 100% (2514/2514), done.
# Already up-to-date.

# %%
os.chdir("..")
# !pip install https://github.com/fastai/fastai/archive/master.zip
# Out:
# Collecting https://github.com/fastai/fastai/archive/master.zip
#   Downloading https://github.com/fastai/fastai/archive/master.zip
#      - 83.0MB 42.0MB/s
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: MarkupSafe in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: Pygments in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting awscli (from fastai==0.6)
#   Downloading awscli-1.15.4-py2.py3-none-any.whl (1.3MB)
#     100% |████████████████████████████████| 1.3MB 1.0MB/s
# Collecting bcolz (from fastai==0.6)
#   Downloading bcolz-1.2.0.tar.gz (1.4MB)
#     100% |████████████████████████████████| 1.4MB 934kB/s
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: cycler in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting feather-format (from fastai==0.6)
#   Downloading feather-format-0.4.0.tar.gz
# Collecting graphviz (from fastai==0.6)
#   Downloading graphviz-0.8.2-py2.py3-none-any.whl
# Requirement already satisfied: html5lib in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting ipywidgets (from fastai==0.6)
#   Downloading ipywidgets-7.2.1-py2.py3-none-any.whl (106kB)
#     100% |████████████████████████████████| 112kB 6.5MB/s
# Collecting isoweek (from fastai==0.6)
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl
# Collecting jedi (from fastai==0.6)
#   Downloading jedi-0.11.1-py2.py3-none-any.whl (250kB)
#     100% |████████████████████████████████| 256kB 5.0MB/s
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting jupyter (from fastai==0.6)
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting jupyter-console (from fastai==0.6)
#   Downloading jupyter_console-5.2.0-py2.py3-none-any.whl
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting jupyter_contrib_nbextensions (from fastai==0.6)
#   Downloading jupyter_contrib_nbextensions-0.5.0-py2.py3-none-any.whl (20.9MB)
#     89% |████████████████████████████▊   | 18.7MB 42.7MB/s eta 0:00:01
#     100% |████████████████████████████████| 20.9MB 69kB/s
# Collecting kaggle-cli (from fastai==0.6)
#   Downloading kaggle-cli-0.12.13.tar.gz
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: mistune in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: notebook in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting pandas_summary (from fastai==0.6)
#   Downloading pandas-summary-0.0.41.tar.gz
# Requirement already satisfied: pandocfilters in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting plotnine (from fastai==0.6)
#   Downloading plotnine-0.3.0-py2.py3-none-any.whl (3.4MB)
#     100% |████████████████████████████████| 3.4MB 414kB/s
# Requirement already satisfied: prompt-toolkit in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting qtconsole (from fastai==0.6)
#   Downloading qtconsole-4.3.1-py2.py3-none-any.whl (108kB)
#     100% |████████████████████████████████| 112kB 10.1MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: simplegeneric in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting sklearn_pandas (from fastai==0.6)
#   Downloading sklearn_pandas-1.6.0-py2.py3-none-any.whl
# Requirement already satisfied: terminado in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting torchtext (from fastai==0.6)
#   Downloading torchtext-0.2.3.tar.gz (42kB)
#     100% |████████████████████████████████| 51kB 11.4MB/s
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting tqdm (from fastai==0.6)
#   Downloading tqdm-4.22.0-py2.py3-none-any.whl (42kB)
#     100% |████████████████████████████████| 51kB 11.2MB/s
# Requirement already satisfied: traitlets in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from fastai==0.6)
# Collecting widgetsnbextension (from fastai==0.6)
#   Downloading widgetsnbextension-3.2.1-py2.py3-none-any.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 600kB/s
# Collecting s3transfer<0.2.0,>=0.1.12 (from awscli->fastai==0.6)
#   Downloading s3transfer-0.1.13-py2.py3-none-any.whl (59kB)
#     100% |████████████████████████████████| 61kB 10.0MB/s
# Collecting docutils>=0.10 (from awscli->fastai==0.6)
#   Downloading docutils-0.14-py3-none-any.whl (543kB)
#     99% |████████████████████████████████| 542kB 37.3MB/s eta 0:00:01
#     100% |████████████████████████████████| 552kB 2.4MB/s
# Requirement already satisfied: rsa<=3.5.0,>=3.1.2 in /usr/local/lib/python3.6/dist-packages (from awscli->fastai==0.6)
# Collecting colorama<=0.3.7,>=0.2.5 (from awscli->fastai==0.6)
#   Downloading colorama-0.3.7-py2.py3-none-any.whl
# Collecting botocore==1.10.4 (from awscli->fastai==0.6)
#   Downloading botocore-1.10.4-py2.py3-none-any.whl (4.2MB)
#     100% |████████████████████████████████| 4.2MB 342kB/s
# Collecting pyarrow>=0.4.0 (from feather-format->fastai==0.6)
#   Downloading pyarrow-0.9.0-cp36-cp36m-manylinux1_x86_64.whl (13.7MB)
#     100% |████████████████████████████████| 13.7MB 101kB/s
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython->fastai==0.6)
# Collecting parso==0.1.1 (from jedi->fastai==0.6)
#   Downloading parso-0.1.1-py2.py3-none-any.whl (91kB)
#     100% |████████████████████████████████| 92kB 8.7MB/s
# Collecting jupyter-contrib-core>=0.3.3 (from jupyter_contrib_nbextensions->fastai==0.6)
#   Downloading jupyter_contrib_core-0.3.3-py2.py3-none-any.whl
# Collecting jupyter-highlight-selected-word>=0.1.1 (from jupyter_contrib_nbextensions->fastai==0.6)
#   Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl
# Collecting jupyter-latex-envs>=1.3.8 (from jupyter_contrib_nbextensions->fastai==0.6)
#   Downloading jupyter_latex_envs-1.4.4.tar.gz (855kB)
#     100% |████████████████████████████████| 860kB 1.6MB/s
# Collecting lxml (from jupyter_contrib_nbextensions->fastai==0.6)
#   Downloading lxml-4.2.1-cp36-cp36m-manylinux1_x86_64.whl (5.6MB)
#     100% |████████████████████████████████| 5.7MB 247kB/s
# Collecting jupyter-nbextensions-configurator>=0.4.0 (from jupyter_contrib_nbextensions->fastai==0.6)
#   Downloading jupyter_nbextensions_configurator-0.4.0-py2.py3-none-any.whl (466kB)
#     100% |████████████████████████████████| 471kB 2.6MB/s
# Collecting MechanicalSoup<0.9,>=0.7.0 (from kaggle-cli->fastai==0.6)
#   Downloading MechanicalSoup-0.8.0-py2.py3-none-any.whl
# Requirement already satisfied: beautifulsoup4<4.7,>=4.6.0 in /usr/local/lib/python3.6/dist-packages (from kaggle-cli->fastai==0.6)
# Collecting cliff<2.9,>=2.8.0 (from kaggle-cli->fastai==0.6)
#   Downloading cliff-2.8.1.tar.gz (73kB)
#     100% |████████████████████████████████| 81kB 9.7MB/s
# Collecting configparser (from kaggle-cli->fastai==0.6)
#   Downloading configparser-3.5.0.tar.gz
# Collecting cssselect<1.1,>=1.0.1 (from kaggle-cli->fastai==0.6)
#   Downloading cssselect-1.0.3-py2.py3-none-any.whl
# Collecting progressbar2<3.35,>=3.34.3 (from kaggle-cli->fastai==0.6)
#   Downloading progressbar2-3.34.3-py2.py3-none-any.whl
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.6)
# Collecting mizani>=0.4.1 (from plotnine->fastai==0.6)
#   Downloading mizani-0.4.6-py2.py3-none-any.whl (65kB)
#     100% |████████████████████████████████| 71kB 9.6MB/s
# Requirement already satisfied: statsmodels>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.6)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_pandas->fastai==0.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext->fastai==0.6)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<=3.5.0,>=3.1.2->awscli->fastai==0.6)
# Collecting jmespath<1.0.0,>=0.7.1 (from botocore==1.10.4->awscli->fastai==0.6)
#   Downloading jmespath-0.9.3-py2.py3-none-any.whl
# Collecting PrettyTable<0.8,>=0.7.1 (from cliff<2.9,>=2.8.0->kaggle-cli->fastai==0.6)
#   Downloading prettytable-0.7.2.tar.bz2
# Collecting cmd2>=0.6.7 (from cliff<2.9,>=2.8.0->kaggle-cli->fastai==0.6)
#   Downloading cmd2-0.8.4-py2.py3-none-any.whl (50kB)
#     100% |████████████████████████████████| 51kB 7.8MB/s
# Collecting pbr!=2.1.0,>=2.0.0 (from cliff<2.9,>=2.8.0->kaggle-cli->fastai==0.6)
#   Using cached pbr-4.0.2-py2.py3-none-any.whl
# Collecting stevedore>=1.20.0 (from cliff<2.9,>=2.8.0->kaggle-cli->fastai==0.6)
#   Downloading stevedore-1.28.0-py2.py3-none-any.whl
# Collecting python-utils>=2.1.0 (from progressbar2<3.35,>=3.34.3->kaggle-cli->fastai==0.6)
#   Downloading python_utils-2.3.0-py2.py3-none-any.whl
# Collecting palettable (from mizani>=0.4.1->plotnine->fastai==0.6)
#   Downloading palettable-3.1.0-py2.py3-none-any.whl (78kB)
#     100% |████████████████████████████████| 81kB 10.0MB/s
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.6)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.6)
# Collecting pyperclip (from cmd2>=0.6.7->cliff<2.9,>=2.8.0->kaggle-cli->fastai==0.6)
#   Downloading pyperclip-1.6.0.tar.gz
# Building wheels for collected packages: bcolz, feather-format, kaggle-cli, pandas-summary, torchtext, jupyter-latex-envs, cliff, configparser, PrettyTable, pyperclip
# done
#   Stored in directory: /content/.cache/pip/wheels/78/ba/ff/0ac6555a3e174aa78eb8cf32c798a5bde0de5a2bc10c654e9b
# done
#   Stored in directory: /content/.cache/pip/wheels/9d/de/23/0ca11012cc6b573de3f8187727cfa97a8392a8605e331214e5
# done
#   Stored in directory: /content/.cache/pip/wheels/f0/3c/ff/c98870eeb0ca26250ce6a60dc9be23f547b7ef68b3d6a1c0b5
# done
#   Stored in directory: /content/.cache/pip/wheels/20/29/c9/b3d9f2cbdb6f1eeeb98e263ae687d72e8138a26de91058bd0b
#   Running setup.py bdist_wheel for torchtext ... -
# done
#   Stored in directory: /content/.cache/pip/wheels/af/e2/0e/a6eb84ab88f6f1594960fd9ca2c9aed28872fb468f9bc3464a
# done
#   Stored in directory: /content/.cache/pip/wheels/8d/1a/c8/3a9f5e0105eb88e1972cd06fcca65d8b904dafe67afacc566b
# done
#   Stored in directory: /content/.cache/pip/wheels/30/3a/08/7701daf1bfb21488ef4d5ba56b1a5ae7aab528fc251959f2ac
# done
#   Stored in directory: /content/.cache/pip/wheels/1c/bd/b4/277af3f6c40645661b4cd1c21df26aca0f2e1e9714a1d4cda8
# done
#   Stored in directory: /content/.cache/pip/wheels/0d/08/4d/38d1751a9e86f7f568d619e8e0662fb85241d17df8c90c5d8a
# done
#   Stored in directory: /content/.cache/pip/wheels/a9/22/c3/8116911c3273f6aa0a90ce69c44fb8a6a0e139d79aeda5a73e
# Successfully built bcolz feather-format kaggle-cli pandas-summary torchtext jupyter-latex-envs cliff configparser PrettyTable pyperclip
# Installing collected packages: docutils, jmespath, botocore, s3transfer, colorama, awscli, bcolz, pyarrow, feather-format, graphviz, widgetsnbextension, ipywidgets, isoweek, parso, jedi, jupyter-console, qtconsole, jupyter, jupyter-contrib-core, jupyter-highlight-selected-word, jupyter-latex-envs, lxml, jupyter-nbextensions-configurator, jupyter-contrib-nbextensions, MechanicalSoup, PrettyTable, pyperclip, cmd2, pbr, stevedore, cliff, configparser, cssselect, python-utils, progressbar2, kaggle-cli, pandas-summary, palettable, mizani, plotnine, sklearn-pandas, tqdm, torchtext, fastai
# done
# Successfully installed MechanicalSoup-0.8.0 PrettyTable-0.7.2 awscli-1.15.4 bcolz-1.2.0 botocore-1.10.4 cliff-2.8.1 cmd2-0.8.4 colorama-0.3.7 configparser-3.5.0 cssselect-1.0.3 docutils-0.14 fastai-0.6 feather-format-0.4.0 graphviz-0.8.2 ipywidgets-7.2.1 isoweek-1.3.3 jedi-0.11.1 jmespath-0.9.3 jupyter-1.0.0 jupyter-console-5.2.0 jupyter-contrib-core-0.3.3 jupyter-contrib-nbextensions-0.5.0 jupyter-highlight-selected-word-0.2.0 jupyter-latex-envs-1.4.4 jupyter-nbextensions-configurator-0.4.0 kaggle-cli-0.12.13 lxml-4.2.1 mizani-0.4.6 palettable-3.1.0 pandas-summary-0.0.41 parso-0.1.1 pbr-4.0.2 plotnine-0.3.0 progressbar2-3.34.3 pyarrow-0.9.0 pyperclip-1.6.0 python-utils-2.3.0 qtconsole-4.3.1 s3transfer-0.1.13 sklearn-pandas-1.6.0 stevedore-1.28.0 torchtext-0.2.3 tqdm-4.22.0 widgetsnbextension-3.2.1

# %%
# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch

# %%
# !pip install ipywidgets==6.0.0
# Out:
# Collecting ipywidgets==6.0.0
#   Downloading ipywidgets-6.0.0-py2.py3-none-any.whl (46kB)
#     100% |████████████████████████████████| 51kB 3.2MB/s
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0)
# Collecting widgetsnbextension~=2.0.0 (from ipywidgets==6.0.0)
#   Downloading widgetsnbextension-2.0.1-py2.py3-none-any.whl (1.1MB)
#     100% |████████████████████████████████| 1.1MB 1.1MB/s
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets==6.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets==6.0.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets==6.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=2.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets==6.0.0)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets==6.0.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets==6.0.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets==6.0.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets==6.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets==6.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: MarkupSafe in /usr/local/lib/python3.6/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: mistune>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0)
# Collecting pandocfilters>=1.4.1 (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0)
#   Downloading pandocfilters-1.4.2.tar.gz
# Requirement already satisfied: html5lib!=0.9999,!=0.99999,<0.99999999,>=0.999 in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0)
# Building wheels for collected packages: pandocfilters
# done
#   Stored in directory: /content/.cache/pip/wheels/08/5b/5b/66b3cde6f8215f8345479ef3699d6ddbb860f6ea7072008f8b
# Successfully built pandocfilters
# Installing collected packages: widgetsnbextension, ipywidgets, pandocfilters
#   Found existing installation: widgetsnbextension 3.2.1
#     Uninstalling widgetsnbextension-3.2.1:
#       Successfully uninstalled widgetsnbextension-3.2.1
#   Found existing installation: ipywidgets 7.2.1
#     Uninstalling ipywidgets-7.2.1:
#       Successfully uninstalled ipywidgets-7.2.1
#   Found existing installation: pandocfilters 1.3.0
#     Uninstalling pandocfilters-1.3.0:
#       Successfully uninstalled pandocfilters-1.3.0
# Successfully installed ipywidgets-6.0.0 pandocfilters-1.4.2 widgetsnbextension-2.0.1

# %%
#Now go to your Google Drive and open the notebook
#Make sure you have runtime type for this as well as the notebook in google drive to GPU

# %% [markdown]
# # PyDrive

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

from pathlib import Path
import os

def download_and_save(file_name, file_id):
  downloaded = drive.CreateFile({'id': file_id})
  # fetch file
  downloaded.FetchContent()
  # write file
  with open(file_name,'wb') as f:
       f.write(downloaded.content.read())
      
  print(f'Saved {file_name}')

# %% [markdown]
# # Get dataset(s)

# %%
dataset_path = Path.home() / 'data/old_polish_cars'; dataset_path
# Out:
# PosixPath('/content/data/old_polish_cars')

# %%
# !mkdir -p $dataset_path

# %%
cd $dataset_path
# Out:
# /content/data/old_polish_cars

# %%
ls -la $dataset_path/
# Out:
# total 2032520
# drwxr-xr-x 6 root root      4096 Apr 13 08:43 ./
# drwxr-xr-x 3 root root      4096 Apr 13 06:34 ../
# drwxr-xr-x 4 root root      4096 Apr 13 06:20 old_polish_cars_two_classes_v1/
# drwxr-xr-x 6 root root      4096 Apr 13 07:32 old_polish_cars_two_classes_v1-split/
# -rw-r--r-- 1 root root 299406387 Apr 13 07:30 old_polish_cars_two_classes_v1-split.zip
# -rw-r--r-- 1 root root 299374871 Apr 13 06:47 old_polish_cars_two_classes_v1.zip
# drwxr-xr-x 4 root root      4096 Apr 13 08:25 old_polish_cars_two_classes_v2a-split/
# -rw-r--r-- 1 root root 740936774 Apr 13 08:43 old_polish_cars_two_classes_v2a-split.zip
# drwxr-xr-x 8 root root      4096 Apr 13 08:10 old_polish_cars_two_classes_v2-split/
# -rw-r--r-- 1 root root 741542541 Apr 13 07:59 old_polish_cars_two_classes_v2-split.zip

# %% [markdown]
# ## get old_polish_cars_v5 dataset

# %%
file_name = 'old_polish_cars_v5_photos-2017-11-15.tgz'
file_id = '1I3BH3CQv3gviBq6JrWq72DL577LcnuH3'

download_and_save(file_name, file_id)

# %%
# unpack
# !tar -xf old_polish_cars_v5_photos-2017-11-15.tgz

# %%
cd ~
# Out:
# /content

# %% [markdown]
# ## get old_polish_cars_v5-split dataset

# %%
split_file_dict = {'': ''}
split_file = list(split_file_dict.items())[0]

file_name = 'old_polish_cars_v5_photos-split-2017-11-15.tgz'
file_id = '1_JgAlUNebGH3JUioSPWW-GV_eL4K1txM'

download_and_save(file_name, file_id)

# %%
# unpack
# !tar -xf old_polish_cars_v5_photos-split-2017-11-15.tgz

# %%
cd ~
# Out:
# /content

# %% [markdown]
# ## get old_polish_cars_two_classes_v2a-split dataset
# https://drive.google.com/file/d/1L0XBjL5fFE41OrrahDBWbDrICK2OpiMC/view?usp=sharing

# %%
file_name = dataset_path / 'old_polish_cars_two_classes_v2a-split.zip'
file_id = '1L0XBjL5fFE41OrrahDBWbDrICK2OpiMC'

download_and_save(file_name, file_id)
# Out:
# Saved /content/data/old_polish_cars/old_polish_cars_two_classes_v2a-split.zip

# %%
cd $dataset_path
# Out:
# /content/data/old_polish_cars

# %%
# !unzip -q -o $file_name

# %%
cd ~
# Out:
# /content

# %% [markdown]
# # Monitoring

# %%
# !ls -a
# Out:
# .  ..  .cache  .config	data  datalab  .forever  .ipython  .local  .rnd

# %%
who
# Out:
# GoogleCredentials	 accelerator	 auth	 creds	 get_abbr_impl	 get_abi_tag	 get_impl_ver	 getpass	 os
# path	 platform	 torch	 vcode

# %%
# !uptime
# Out:
#  07:53:06 up  1:25,  0 users,  load average: 0.16, 0.03, 0.05

# %%
cd fastai
# Out:
# /content/fastai

# %%
# !/opt/bin/nvidia-smi
# Out:
# Thu Apr 12 15:26:18 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.111                Driver Version: 384.111                   |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   74C    P0   121W / 149W |   3719MiB / 11439MiB |     29%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
for i in range(3):
  # !top -n 1
# Out:
# =top - 15:27:24 up  1:39,  0 users,  load average: 6.99, 7.19, 6.69
# Tasks:  11 total,   1 running,  10 sleeping,   0 stopped,   0 zombie
# %Cpu(s): 40.0 us,  3.9 sy,  0.0 ni, 55.0 id,  0.9 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13341832 total,   167480 free,  4449016 used,  8725336 buff/cache
# KiB Swap:        0 total,        0 free,        0 used.  8407400 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#  1931 root      20   0 41.649g 3.945g 363404 S 166.7 31.0  64:32.08 python3
#    81 root      20   0  733196  69756  22912 S   6.7  0.5   0:27.62 node
#    91 root      20   0  199716  72256  11960 S   6.7  0.5   0:18.98 jupyter-no+
#  1737 root      20   0 1855576 227780 101832 S   6.7  1.7   0:04.07 python3
#     1 root      20   0   39144   6400   5024 S   0.0  0.0   0:00.09 run.sh
#    71 root      20   0  678296  40440  21708 S   0.0  0.3   0:03.39 node
#   752 root      20   0  127780   6512   4304 S   0.0  0.0   0:00.14 dirmngr
#  1179 root      20   0  184200  35440   8640 S   0.0  0.3   0:02.63 google-dri+
#  1721 root      20   0  677288 127112  39308 S   0.0  1.0   0:01.95 python3
#  2172 root      20   0   33964   4840   3736 S   0.0  0.0   0:01.28 sh
#  2173 root      20   0   65360   6856   5100 R   0.0  0.1   0:00.00 top
# >
# =top - 15:27:30 up  1:39,  0 users,  load average: 7.30, 7.25, 6.72
# Tasks:  11 total,   1 running,  10 sleeping,   0 stopped,   0 zombie
# %Cpu(s): 40.1 us,  3.9 sy,  0.0 ni, 55.0 id,  0.9 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13341832 total,   167464 free,  4448936 used,  8725432 buff/cache
# KiB Swap:        0 total,        0 free,        0 used.  8407476 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#  1931 root      20   0 41.649g 3.945g 363404 S 193.3 31.0  64:42.02 python3
#    81 root      20   0  733196  69732  22912 S  13.3  0.5   0:27.68 node
#    91 root      20   0  199716  72256  11960 S   6.7  0.5   0:19.02 jupyter-no+
#     1 root      20   0   39144   6400   5024 S   0.0  0.0   0:00.09 run.sh
#    71 root      20   0  678296  40440  21708 S   0.0  0.3   0:03.39 node
#   752 root      20   0  127780   6512   4304 S   0.0  0.0   0:00.14 dirmngr
#  1179 root      20   0  184200  35440   8640 S   0.0  0.3   0:02.63 google-dri+
#  1721 root      20   0  677288 127112  39308 S   0.0  1.0   0:01.95 python3
#  1737 root      20   0 1855576 227780 101832 S   0.0  1.7   0:04.09 python3
#  2174 root      20   0   33964   4680   3564 S   0.0  0.0   0:01.27 sh
#  2175 root      20   0   65360   6892   5140 R   0.0  0.1   0:00.00 top
# >
# =top - 15:27:35 up  1:39,  0 users,  load average: 7.27, 7.25, 6.72
# Tasks:  11 total,   1 running,  10 sleeping,   0 stopped,   0 zombie
# %Cpu(s): 40.1 us,  3.9 sy,  0.0 ni, 54.9 id,  0.9 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13341832 total,   166764 free,  4449572 used,  8725496 buff/cache
# KiB Swap:        0 total,        0 free,        0 used.  8406840 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#  1931 root      20   0 41.649g 3.945g 363404 S 170.6 31.0  64:50.08 python3
#    81 root      20   0  733196  69928  22912 S   5.9  0.5   0:27.73 node
#     1 root      20   0   39144   6400   5024 S   0.0  0.0   0:00.09 run.sh
#    71 root      20   0  678296  40440  21708 S   0.0  0.3   0:03.40 node
#    91 root      20   0  199716  72256  11960 S   0.0  0.5   0:19.04 jupyter-no+
#   752 root      20   0  127780   6512   4304 S   0.0  0.0   0:00.14 dirmngr
#  1179 root      20   0  184200  35440   8640 S   0.0  0.3   0:02.63 google-dri+
#  1721 root      20   0  677288 127112  39308 S   0.0  1.0   0:01.95 python3
#  1737 root      20   0 1855576 227780 101832 S   0.0  1.7   0:04.11 python3
#  2176 root      20   0   33964   4744   3636 S   0.0  0.0   0:01.29 sh
#  2177 root      20   0   65356   6920   5168 R   0.0  0.1   0:00.00 top
# >
# =top - 15:27:39 up  1:40,  0 users,  load average: 7.27, 7.25, 6.72
# Tasks:  11 total,   2 running,   9 sleeping,   0 stopped,   0 zombie
# %Cpu(s): 40.1 us,  3.9 sy,  0.0 ni, 54.9 id,  0.9 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13341832 total,   168012 free,  4448136 used,  8725684 buff/cache
# KiB Swap:        0 total,        0 free,        0 used.  8408280 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#  1931 root      20   0 41.649g 3.945g 363404 R 186.7 31.0  64:56.31 python3
#     1 root      20   0   39144   6400   5024 S   0.0  0.0   0:00.09 run.sh
#    71 root      20   0  678296  40440  21708 S   0.0  0.3   0:03.40 node
#    81 root      20   0  733196  70284  22912 S   0.0  0.5   0:27.75 node
#    91 root      20   0  199716  72256  11960 S   0.0  0.5   0:19.06 jupyter-no+
#   752 root      20   0  127780   6512   4304 S   0.0  0.0   0:00.14 dirmngr
#  1179 root      20   0  184200  35440   8640 S   0.0  0.3   0:02.63 google-dri+
#  1721 root      20   0  677288 127112  39308 S   0.0  1.0   0:01.95 python3
#  1737 root      20   0 1855576 227780 101832 S   0.0  1.7   0:04.13 python3
#  2178 root      20   0   33960   4988   3884 S   0.0  0.0   0:01.27 sh
#  2179 root      20   0   65360   6844   5092 R   0.0  0.1   0:00.00 top
# >
# =top - 15:27:41 up  1:40,  0 users,  load average: 6.93, 7.18, 6.70
# Tasks:  11 total,   1 running,  10 sleeping,   0 stopped,   0 zombie
# %Cpu(s): 40.2 us,  3.9 sy,  0.0 ni, 54.9 id,  0.9 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13341832 total,   167372 free,  4448708 used,  8725752 buff/cache
# KiB Swap:        0 total,        0 free,        0 used.  8407708 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#  1931 root      20   0 41.649g 3.945g 363404 S  93.3 31.0  64:58.76 python3
#     1 root      20   0   39144   6400   5024 S   0.0  0.0   0:00.09 run.sh
#    71 root      20   0  678296  40440  21708 S   0.0  0.3   0:03.40 node
#    81 root      20   0  733196  70460  22912 S   0.0  0.5   0:27.78 node
#    91 root      20   0  199716  72256  11960 S   0.0  0.5   0:19.08 jupyter-no+
#   752 root      20   0  127780   6512   4304 S   0.0  0.0   0:00.14 dirmngr
#  1179 root      20   0  184200  35440   8640 S   0.0  0.3   0:02.63 google-dri+
#  1721 root      20   0  677288 127112  39308 S   0.0  1.0   0:01.95 python3
#  1737 root      20   0 1855576 227780 101832 S   0.0  1.7   0:04.15 python3
#  2180 root      20   0   33964   5076   3984 S   0.0  0.0   0:01.28 sh
#  2181 root      20   0   65356   6896   5140 R   0.0  0.1   0:00.00 top
# >

# %%
# !top -h
# Out:
#   procps-ng 3.3.12
# Usage:
#   top -hv | -bcHiOSs -d secs -n max -u|U user -p pid(s) -o field -w [cols]

# %%
import os
import psutil

def print_memsize():
  process = psutil.Process(os.getpid())
  print(f'{process.memory_info().rss / 1024**3:.5} GB')
  
print_memsize()
# Out:
# 2.2789 GB

# %%
print_memsize()
# Out:
# 0.12072 GB

# %% [markdown]
# # New Section

# %%
# !ps ax|grep python
# Out:
#    91 ?        Sl     0:26 /usr/bin/python /usr/local/bin/jupyter-notebook -y --no-browser --log-level=DEBUG --debug --NotebookApp.allow_origin="*" --NotebookApp.log_format="%(message)s" --NotebookApp.token= --Session.key="" --Session.keyfile="" --ContentsManager.untitled_directory="Untitled Folder" --ContentsManager.untitled_file="Untitled File" --ContentsManager.untitled_notebook="Untitled Notebook" --NotebookNotary.algorithm="sha1" --KernelManager.autorestart=True --MultiKernelManager.default_kernel_name="python2" --ip="127.0.0.1" --port=9000 --port-retries=0 --notebook-dir="/content" --NotebookNotary.algorithm=sha256 --NotebookNotary.secret_file=/content/datalab/.config/notary_secret --NotebookApp.base_url=/tun/m/gpu-1aec9c34-733d-46ac-b2db-e219d0d430f7/
#  1868 ?        Ssl    0:04 /usr/bin/python3 -m ipykernel_launcher -f /content/.local/share/jupyter/runtime/kernel-b2adf431-0dc7-4dae-8bf0-a8cb86d4ee66.json
#  2682 ?        Ssl    0:01 /usr/bin/python3 -m ipykernel_launcher -f /content/.local/share/jupyter/runtime/kernel-2048318a-980d-48af-909a-160d4c0ba76f.json
#  2698 pts/1    Ss+    0:01 /bin/sh -c ps ax|grep python
#  2700 pts/1    S+     0:00 grep python

# %%
# !ls -lah  /content/data/old_polish_cars/old_polish_cars_v5_photos-split/valid/Autobus\ Jelcz\ MZK
# Out:
# total 25M
# drwxr-xr-x  2 349452163 349400513 4.0K Nov 15 05:41 .
# drwxr-xr-x 12 349452163 349400513 4.0K Nov 15 05:41 ..
# -rw-r--r--  1 349452163 349400513  84K Nov  9 20:44 Autobus.Jelcz.33_1487455266.66_ddd.jpg
# -rw-r--r--  1 349452163 349400513  58K Nov  9 20:44 Autobus.Jelcz.48_1487455309.35_ddd.jpg
# -rw-r--r--  1 349452163 349400513  47K Nov  9 20:44 Autobus.Jelcz.70_1487455346.74.jpg
# -rw-r--r--  1 349452163 349400513 139K Nov  9 20:44 Autobus.Jelcz.90_1487455377.41.jpg
# -rw-r--r--  1 349452163 349400513 292K Nov  9 20:44 Berliet.PR100.000005.jpg
# -rw-r--r--  1 349452163 349400513 144K Nov  9 20:44 Berliet.PR100.000007.jpg
# -rw-r--r--  1 349452163 349400513 347K Nov  9 20:44 Berliet.PR100.000015.jpg
# -rw-r--r--  1 349452163 349400513  38K Nov  9 20:44 Berliet.PR100.000025.jpg
# -rw-r--r--  1 349452163 349400513 494K Nov  9 20:44 Berliet.PR100.000028.jpg
# -rw-r--r--  1 349452163 349400513  32K Nov  9 20:44 Berliet.PR100.000059_ddd.jpg
# -rw-r--r--  1 349452163 349400513  56K Nov  9 20:44 Berliet.PR100.000065_ddd.jpg
# -rw-r--r--  1 349452163 349400513  70K Nov  9 20:44 Berliet.PR100.000095_ddd.jpg
# -rw-r--r--  1 349452163 349400513 102K Nov  9 20:44 Berliet.PR100.000099_ddd.jpg
# -rw-r--r--  1 349452163 349400513 286K Nov  9 20:44 Berliet.PR100.000107.jpg
# -rw-r--r--  1 349452163 349400513 109K Nov  9 20:44 Berliet.PR100.000129.jpg
# -rw-r--r--  1 349452163 349400513 268K Nov  9 20:44 Berliet.PR100.000161.jpg
# -rw-r--r--  1 349452163 349400513 130K Nov  9 20:44 Berliet.PR100.000170.jpg
# -rw-r--r--  1 349452163 349400513 112K Nov  9 20:44 Berliet.PR100.000175_ddd.jpg
# -rw-r--r--  1 349452163 349400513 302K Nov  9 20:44 Berliet.PR100.000179.jpg
# -rw-r--r--  1 349452163 349400513 156K Nov  9 20:44 Berliet.PR100.000185.jpg
# -rw-r--r--  1 349452163 349400513  99K Nov  9 20:44 Berliet.PR100.000231.jpg
# -rw-r--r--  1 349452163 349400513  27K Nov  9 20:44 Berliet.PR100.000236.jpg
# -rw-r--r--  1 349452163 349400513 154K Nov  9 20:44 Berliet.PR100.000253.jpg
# -rw-r--r--  1 349452163 349400513 102K Nov  9 20:44 Berliet.PR100.000265_ddd.jpg
# -rw-r--r--  1 349452163 349400513 102K Nov  9 20:44 Berliet.PR100.000265.jpg
# -rw-r--r--  1 349452163 349400513  27K Nov  9 20:44 Berliet.PR100.000273.jpg
# -rw-r--r--  1 349452163 349400513  54K Nov  9 20:44 Berliet.PR100.000292_ddd.jpg
# -rw-r--r--  1 349452163 349400513 149K Nov  9 20:44 Berliet.PR100.000297_ddd.jpg
# -rw-r--r--  1 349452163 349400513 196K Nov  9 20:44 Berliet.PR100.000302.jpg
# -rw-r--r--  1 349452163 349400513 145K Nov  9 20:44 Berliet.PR100.000308.jpg
# -rw-r--r--  1 349452163 349400513 401K Nov  9 20:44 Berliet.PR100.000326.jpg
# -rw-r--r--  1 349452163 349400513 425K Nov  9 20:44 Berliet.PR100.000331_ddd.jpg
# -rw-r--r--  1 349452163 349400513  80K Nov  9 20:44 Berliet.PR100.000334.jpg
# -rw-r--r--  1 349452163 349400513 171K Nov  9 20:44 Berliet.PR100.000337_ddd.jpg
# -rw-r--r--  1 349452163 349400513  55K Nov  9 20:44 Berliet.PR100.000358_ddd.jpg
# -rw-r--r--  1 349452163 349400513  51K Nov  9 20:44 Berliet.PR100.000365.jpg
# -rw-r--r--  1 349452163 349400513 105K Nov  9 20:44 Berliet.PR100.000387.jpg
# -rw-r--r--  1 349452163 349400513  96K Nov  9 20:44 Berliet.PR100.000409.jpg
# -rw-r--r--  1 349452163 349400513  49K Nov  9 20:44 Berliet.PR100.000413_ddd.jpg
# -rw-r--r--  1 349452163 349400513  54K Nov  9 20:44 Berliet.PR100.000420.jpg
# -rw-r--r--  1 349452163 349400513  44K Nov  9 20:44 Berliet.PR100.000422_ddd.jpg
# -rw-r--r--  1 349452163 349400513 375K Nov  9 20:44 Berliet.PR100.000435_ddd.jpg
# -rw-r--r--  1 349452163 349400513 107K Nov  9 20:44 Jelcz.080.000023.jpg
# -rw-r--r--  1 349452163 349400513  66K Nov  9 20:44 Jelcz.080.000040_ddd.jpg
# -rw-r--r--  1 349452163 349400513  66K Nov  9 20:44 Jelcz.080.000040.jpg
# -rw-r--r--  1 349452163 349400513  38K Nov  9 20:44 Jelcz.080.000047_ddd.jpg
# -rw-r--r--  1 349452163 349400513  50K Nov  9 20:44 Jelcz.080.000074.jpg
# -rw-r--r--  1 349452163 349400513 210K Nov  9 20:44 Jelcz.080.000111.jpg
# -rw-r--r--  1 349452163 349400513 285K Nov  9 20:44 Jelcz.080.000139.jpg
# -rw-r--r--  1 349452163 349400513  64K Nov  9 20:44 Jelcz.080.000185.jpg
# -rw-r--r--  1 349452163 349400513 275K Nov  9 20:44 Jelcz.080.000228_ddd.jpg
# -rw-r--r--  1 349452163 349400513 163K Nov  9 20:44 Jelcz.080.000277.jpg
# -rw-r--r--  1 349452163 349400513 209K Nov  9 20:44 Jelcz.PR110M.000013.jpg
# -rw-r--r--  1 349452163 349400513 210K Nov  9 20:44 Jelcz.PR110M.000032.jpg
# -rw-r--r--  1 349452163 349400513 249K Nov  9 20:44 Jelcz.PR110M.000049.jpg
# -rw-r--r--  1 349452163 349400513 134K Nov  9 20:44 Jelcz.PR110M.000069_ddd.jpg
# -rw-r--r--  1 349452163 349400513 151K Nov  9 20:44 Jelcz.PR110M.000070.jpg
# -rw-r--r--  1 349452163 349400513  92K Nov  9 20:44 Jelcz.PR110M.000079.jpg
# -rw-r--r--  1 349452163 349400513 465K Nov  9 20:44 Jelcz.PR110M.000085_ddd.jpg
# -rw-r--r--  1 349452163 349400513 103K Nov  9 20:44 Jelcz.PR110M.000091.jpg
# -rw-r--r--  1 349452163 349400513 154K Nov  9 20:44 Jelcz.PR110M.000095_ddd.jpg
# -rw-r--r--  1 349452163 349400513  21K Nov  9 20:44 Jelcz.PR110M.000106.jpg
# -rw-r--r--  1 349452163 349400513 367K Nov  9 20:44 Jelcz.PR110M.000115.jpg
# -rw-r--r--  1 349452163 349400513 149K Nov  9 20:44 Jelcz.PR110M.000123.jpg
# -rw-r--r--  1 349452163 349400513 143K Nov  9 20:44 Jelcz.PR110M.000125_ddd.jpg
# -rw-r--r--  1 349452163 349400513 231K Nov  9 20:44 Jelcz.PR110M.000134.jpg
# -rw-r--r--  1 349452163 349400513 182K Nov  9 20:44 Jelcz.PR110M.000148_ddd.jpg
# -rw-r--r--  1 349452163 349400513 105K Nov  9 20:44 Jelcz.PR110M.000149.jpg
# -rw-r--r--  1 349452163 349400513 180K Nov  9 20:44 Jelcz.PR110M.000155.jpg
# -rw-r--r--  1 349452163 349400513 359K Nov  9 20:44 Jelcz.PR110M.000162_ddd.jpg
# -rw-r--r--  1 349452163 349400513  65K Nov  9 20:44 Jelcz.PR110M.000172.jpg
# -rw-r--r--  1 349452163 349400513 352K Nov  9 20:44 Jelcz.PR110M.000181.jpg
# -rw-r--r--  1 349452163 349400513  74K Nov  9 20:44 Jelcz.PR110M.000185_ddd.jpg
# -rw-r--r--  1 349452163 349400513  86K Nov  9 20:44 Jelcz.PR110M.000229.jpg
# -rw-r--r--  1 349452163 349400513  72K Nov  9 20:44 Jelcz.PR110M.000231.jpg
# -rw-r--r--  1 349452163 349400513  94K Nov  9 20:44 Jelcz.PR110M.000267.jpg
# -rw-r--r--  1 349452163 349400513 138K Nov  9 20:44 Jelcz.PR110M.000271.jpg
# -rw-r--r--  1 349452163 349400513 109K Nov  9 20:44 Jelcz.PR110M.000305.jpg
# -rw-r--r--  1 349452163 349400513  77K Nov  9 20:44 Jelcz.PR110M.000308_ddd.jpg
# -rw-r--r--  1 349452163 349400513  57K Nov  9 20:44 Jelcz.PR110M.000320.jpg
# -rw-r--r--  1 349452163 349400513  23K Nov 13 15:09 Jelcz.PR110M.000334.jpg
# -rw-r--r--  1 349452163 349400513 1.8M Nov  9 20:44 Jelcz.PR110M.000350.jpg
# -rw-r--r--  1 349452163 349400513 778K Nov  9 20:44 Jelcz.PR110M.000355.jpg
# -rw-r--r--  1 349452163 349400513 142K Nov  9 20:44 Jelcz.PR110M.000371.jpg
# -rw-r--r--  1 349452163 349400513 219K Nov  9 20:44 Jelcz.PR110M.000379_ddd.jpg
# -rw-r--r--  1 349452163 349400513  93K Nov  9 20:44 Jelcz.PR110M.000397.jpg
# -rw-r--r--  1 349452163 349400513 235K Nov  9 20:44 Jelcz.PR110M.000404.jpg
# -rw-r--r--  1 349452163 349400513 163K Nov  9 20:44 Jelcz.PR110M.000415_ddd.jpg
# -rw-r--r--  1 349452163 349400513 701K Nov 13 15:10 Jelcz.PR110M.000420.jpg
# -rw-r--r--  1 349452163 349400513 315K Nov  9 20:44 Jelcz.PR110M.000424.jpg
# -rw-r--r--  1 349452163 349400513  48K Nov  9 20:44 Jelcz.PR110M.000439.jpg
# -rw-r--r--  1 349452163 349400513 111K Nov  9 20:44 Jelcz.PR110M.000445.jpg
# -rw-r--r--  1 349452163 349400513 145K Nov  9 20:44 Jelcz.PR110M.000451.jpg
# -rw-r--r--  1 349452163 349400513 164K Nov  9 20:44 Jelcz.PR110M.000478.jpg
# -rw-r--r--  1 349452163 349400513 204K Nov  9 20:44 Jelcz.PR110M.000481_ddd.jpg
# -rw-r--r--  1 349452163 349400513 7.5M Nov  9 20:44 Jelcz.PR110M.000507.jpg
# -rw-r--r--  1 349452163 349400513 284K Nov  9 20:44 Jelcz.PR110M.000514_ddd.jpg
# -rw-r--r--  1 349452163 349400513  22K Nov  9 20:44 Jelcz.PR110M.000535.jpg

# %% [markdown]
# # ssh access

# %%
# !ssh-agent bash
# Out:
# root@782b13940ddf:~# ^C
#
# root@782b13940ddf:~#

# %%
cd ~
# Out:
# /content

# %%
download_and_save('id_rsa', '1Bu--WblAk0uBOXvDOeCTHm8-wlAfoKfc')

# %%
# !ls
# Out:
# data  datalab  drive  fastai  id_rsa  lr_plot.png

# %% [markdown]
# # plots_wcz.py

# %%
cd ~
# Out:
# /content

# %%
download_and_save('plots_wcz.py', '1CIc_hlYNzypzZFnFi4iQXtoyLj1C7-vS')

# %%
# !cp ~/plots_wcz.py /usr/local/lib/python3.6/dist-packages/fastai

# %%
ls -la /content
# Out:
# total 56
# drwxr-xr-x 1 root root 4096 Apr 12 14:38 ./
# drwxr-xr-x 1 root root 4096 Apr 12 13:50 ../
# drwx------ 4 root root 4096 Apr 12 13:51 .cache/
# drwxr-xr-x 3 root root 4096 Apr 12 13:51 .config/
# drwxr-xr-x 3 root root 4096 Apr 12 14:00 data/
# drwxr-xr-x 1 root root 4096 Apr 12 13:53 datalab/
# drwxr-xr-x 2 root root 4096 Apr 12 13:54 drive/
# drwxr-xr-x 8 root root 4096 Apr 12 13:54 fastai/
# drwxr-xr-x 4 root root 4096 Apr 12 13:51 .forever/
# drwx------ 3 root root 4096 Apr 12 13:53 .gdfuse/
# drwxr-xr-x 5 root root 4096 Apr 12 13:51 .ipython/
# drwx------ 3 root root 4096 Apr 12 13:51 .local/
# -rw-r--r-- 1 root root 2253 Apr 12 14:38 plots_wcz.py
# -rw------- 1 root root 1024 Apr 12 13:51 .rnd

# %%
ls -la /content/fastai/fastai
# Out:
# total 284
# drwxr-xr-x 4 root root  4096 Apr 12 13:54 ./
# drwxr-xr-x 8 root root  4096 Apr 12 13:54 ../
# -rw-r--r-- 1 root root  3230 Apr 12 13:54 adaptive_softmax.py
# -rw-r--r-- 1 root root  9130 Apr 12 13:54 column_data.py
# -rw-r--r-- 1 root root  7470 Apr 12 13:54 conv_learner.py
# -rw-r--r-- 1 root root  4271 Apr 12 13:54 core.py
# -rw-r--r-- 1 root root  3984 Apr 12 13:54 dataloader.py
# -rw-r--r-- 1 root root 19747 Apr 12 13:54 dataset.py
# -rw-r--r-- 1 root root  1800 Apr 12 13:54 executors.py
# -rw-r--r-- 1 root root  2118 Apr 12 13:54 fp16.py
# -rw-r--r-- 1 root root     9 Apr 12 13:54 .gitignore
# drwxr-xr-x 2 root root  4096 Apr 12 13:54 images/
# -rw-r--r-- 1 root root  1863 Apr 12 13:54 imports.py
# -rw-r--r-- 1 root root   334 Apr 12 13:54 initializers.py
# -rw-r--r-- 1 root root     0 Apr 12 13:54 __init__.py
# -rw-r--r-- 1 root root   631 Apr 12 13:54 io.py
# -rw-r--r-- 1 root root  2125 Apr 12 13:54 layer_optimizer.py
# -rw-r--r-- 1 root root   586 Apr 12 13:54 layers.py
# -rw-r--r-- 1 root root 15736 Apr 12 13:54 learner.py
# -rw-r--r-- 1 root root  9714 Apr 12 13:54 lm_rnn.py
# -rw-r--r-- 1 root root   415 Apr 12 13:54 losses.py
# -rw-r--r-- 1 root root   546 Apr 12 13:54 metrics.py
# -rw-r--r-- 1 root root  8479 Apr 12 13:54 model.py
# drwxr-xr-x 3 root root  4096 Apr 12 13:54 models/
# -rw-r--r-- 1 root root 14065 Apr 12 13:54 nlp.py
# -rw-r--r-- 1 root root  8811 Apr 12 13:54 plots.py
# -rw-r--r-- 1 root root  6343 Apr 12 13:54 rnn_reg.py
# -rw-r--r-- 1 root root    92 Apr 12 13:54 rnn_train.py
# -rw-r--r-- 1 root root    72 Apr 12 13:54 set_spawn.py
# -rw-r--r-- 1 root root 15627 Apr 12 13:54 sgdr.py
# -rw-r--r-- 1 root root 15326 Apr 12 13:54 structured.py
# -rw-r--r-- 1 root root  8358 Apr 12 13:54 text.py
# -rw-r--r-- 1 root root  4253 Apr 12 13:54 torch_imports.py
# -rw-r--r-- 1 root root 25554 Apr 12 13:54 transforms.py
# -rw-r--r-- 1 root root  4479 Apr 12 13:54 utils.py

# %%
import fastai
import fastai.plots
print(fastai.__file__)
print(fastai.plots.__file__)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/__init__.py
# /usr/local/lib/python3.6/dist-packages/fastai/plots.py

# %%
ls -la /usr/local/lib/python3.6/dist-packages/fastai/
# Out:
# total 284
# drwxr-sr-x 4 root staff  4096 Apr 12 14:41 ./
# drwxrwsr-x 1 root staff  4096 Apr 12 14:00 ../
# -rw-r--r-- 1 root staff  3230 Apr 12 13:54 adaptive_softmax.py
# -rw-r--r-- 1 root staff  9130 Apr 12 13:54 column_data.py
# -rw-r--r-- 1 root staff  7470 Apr 12 13:54 conv_learner.py
# -rw-r--r-- 1 root staff  4271 Apr 12 13:54 core.py
# -rw-r--r-- 1 root staff  3984 Apr 12 13:54 dataloader.py
# -rw-r--r-- 1 root staff 19747 Apr 12 13:54 dataset.py
# -rw-r--r-- 1 root staff  1800 Apr 12 13:54 executors.py
# -rw-r--r-- 1 root staff  2118 Apr 12 13:54 fp16.py
# -rw-r--r-- 1 root staff  1863 Apr 12 13:54 imports.py
# -rw-r--r-- 1 root staff   334 Apr 12 13:54 initializers.py
# -rw-r--r-- 1 root staff     0 Apr 12 13:54 __init__.py
# -rw-r--r-- 1 root staff   631 Apr 12 13:54 io.py
# -rw-r--r-- 1 root staff  2125 Apr 12 13:54 layer_optimizer.py
# -rw-r--r-- 1 root staff   586 Apr 12 13:54 layers.py
# -rw-r--r-- 1 root staff 15736 Apr 12 13:54 learner.py
# -rw-r--r-- 1 root staff  9714 Apr 12 13:54 lm_rnn.py
# -rw-r--r-- 1 root staff   415 Apr 12 13:54 losses.py
# -rw-r--r-- 1 root staff   546 Apr 12 13:54 metrics.py
# -rw-r--r-- 1 root staff  8479 Apr 12 13:54 model.py
# drwxr-sr-x 4 root staff  4096 Apr 12 13:59 models/
# -rw-r--r-- 1 root staff 14065 Apr 12 13:54 nlp.py
# -rw-r--r-- 1 root staff  8811 Apr 12 13:54 plots.py
# -rw-r--r-- 1 root staff  2253 Apr 12 14:41 plots_wcz.py
# drwxr-sr-x 2 root staff  4096 Apr 12 13:59 __pycache__/
# -rw-r--r-- 1 root staff  6343 Apr 12 13:54 rnn_reg.py
# -rw-r--r-- 1 root staff    92 Apr 12 13:54 rnn_train.py
# -rw-r--r-- 1 root staff    72 Apr 12 13:54 set_spawn.py
# -rw-r--r-- 1 root staff 15627 Apr 12 13:54 sgdr.py
# -rw-r--r-- 1 root staff 15326 Apr 12 13:54 structured.py
# -rw-r--r-- 1 root staff  8358 Apr 12 13:54 text.py
# -rw-r--r-- 1 root staff  4253 Apr 12 13:54 torch_imports.py
# -rw-r--r-- 1 root staff 25554 Apr 12 13:54 transforms.py
# -rw-r--r-- 1 root staff  4479 Apr 12 13:54 utils.py

# %% [markdown]
# # setup inference, test1 folder

# %%
# %%bash
# export PATH2="data/old_polish_cars/old_polish_cars_v5_photos-split/"
# mkdir -p ${PATH2}test1
# cp "${PATH2}valid/Fiat 126p Maluch/fp126p.2.000354.jpg" ${PATH2}test1

# %%
# !ls "/content/data/old_polish_cars/old_polish_cars_v5_photos-split/test1"
# Out:
# fp126p.2.000354.jpg

# %% [markdown]
# # clean v2-split dataset

# %%
cd /content/data/old_polish_cars/old_polish_cars_two_classes_v2-split/train/maluch/
# Out:
# /content/data/old_polish_cars/old_polish_cars_two_classes_v2-split/train/maluch

# %%
cd ..
# Out:
# /content/data/old_polish_cars/old_polish_cars_two_classes_v2-split

# %%
mkdir train_maluch_bad

# %%
mv train/maluch/fp126p.2.000035.gif train_maluch_bad/

# %%
mv train/maluch/*.gif train_maluch_bad/

# %%
# !find .|grep .DS_Store
# Out:
# ./train/polonez/.DS_Store

# %%
rm train/maluch/.DS_Store
# Out:
# rm: cannot remove 'train/maluch/.DS_Store': No such file or directory

# %%
rm train/polonez/.DS_Store
# Out:
# rm: cannot remove 'train/polonez/.DS_Store': No such file or directory

# %%
mkdir train_polonez_bad

# %%
mv train/polonez/*.gif train_polonez_bad/

# %%
ls -l train_polonez_bad/
# Out:
# total 40
# -rw-r--r-- 1 root root 40774 Feb 20  2017 Polonez.1.000389.gif

# %%
ls -l train_maluch_bad/
# Out:
# total 552
# -rw-r--r-- 1 root root  55821 Feb 20  2017 fp126p.1.000056.gif
# -rw-r--r-- 1 root root 194846 Feb 20  2017 fp126p.2.000035.gif
# -rw-r--r-- 1 root root 194998 Feb 20  2017 fp126p.2.000253.gif
# -rw-r--r-- 1 root root  36285 Feb 20  2017 fp126p.2.000344.gif
# -rw-r--r-- 1 root root  74759 Feb 20  2017 fp126p.4.000120.gif
