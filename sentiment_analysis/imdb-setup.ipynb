# %% [markdown]
# # SpaCy installation

# %%
# !pip install -U spacy

# %%
# !python -m spacy download en

# %% [markdown]
# # get imdb dataset

# %%
cd ~

# %%
mkdir -p data

# %%
cd data

# %%
# !curl -OL http://files.fast.ai/data/aclImdb.tgz

# %%
# !tar -xzf aclImdb.tgz

# %%
cd ~

# %% [markdown]
# # Virtual Machine monitoring

# %%
import os
import psutil

def print_memsize():
  process = psutil.Process(os.getpid())
  print(f'{process.memory_info().rss / 1024**3:.5} GB')

# %%
print_memsize()
# Out:
# 0.12226 GB

# %%
# !/opt/bin/nvidia-smi
# Out:
# Wed Apr 18 15:33:20 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.111                Driver Version: 384.111                   |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   27C    P8    27W / 149W |     11MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !top -n 1
# Out:
# =top - 15:30:49 up  3:43,  2 users,  load average: 0.32, 0.12, 0.03
# Tasks:  23 total,   1 running,  22 sleeping,   0 stopped,   0 zombie
# %Cpu(s):  3.6 us,  1.1 sy,  0.0 ni, 94.8 id,  0.5 wa,  0.0 hi,  0.0 si,  0.0 st
# KiB Mem : 13341832 total,  3950268 free,  6824716 used,  2566848 buff/cache
# KiB Swap:        0 total,        0 free,        0 used.  6037852 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#    79 root      20   0  714760  67652  22644 S   6.7  0.5   0:19.75 node
#  3882 root      20   0  687484 128772  39796 S   6.7  1.0   0:01.86 python3
#     1 root      20   0   39148   6444   5064 S   0.0  0.0   0:00.08 run.sh
#    69 root      20   0  678296  39740  21680 S   0.0  0.3   0:02.27 node
#    89 root      20   0  187032  59964  12104 S   0.0  0.4   0:13.39 jupyter-no+
#   110 root      20   0  687648 127604  39012 S   0.0  1.0   0:33.09 python3
#   766 root      20   0  127784   5236   3044 S   0.0  0.0   0:00.30 dirmngr
#  1193 root      20   0  211852  51716   5604 S   0.0  0.4   0:07.09 google-dri+
#  1943 root      20   0   95060   4880   2760 S   0.0  0.0   0:00.01 sshd
#  2258 root      20   0   28612   3876   3040 S   0.0  0.0   0:01.00 tmux: serv+
#  2259 root      20   0   20208   4096   3488 S   0.0  0.0   0:00.00 bash
#  3161 root      20   0   77476  10396   3620 S   0.0  0.1   0:00.58 ssh
#  3211 root      20   0  124264  10476   8056 S   0.0  0.1   0:00.04 sshd
#  3225 root      20   0   12976   2040   1916 S   0.0  0.0   0:00.00 sftp-server
#  3226 root      20   0  124260  10468   8048 S   0.0  0.1   0:00.02 sshd
#  3240 root      20   0   12976   1968   1844 S   0.0  0.0   0:00.00 sftp-server
#  3464 root      20   0  125288  10592   8064 S   0.0  0.1   0:00.12 sshd        >
