# %%
#Setup Google Drive Integration

# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# !mkdir -p drive
# !google-drive-ocamlfuse drive -o nonempty
# Out:
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
#Fast.AI Setup
# !git clone https://github.com/fastai/fastai.git
import os
os.chdir("fastai")
# !git pull
# Out:
# Cloning into 'fastai'...
# remote: Counting objects: 4520, done.
# remote: Total 4520 (delta 0), reused 0 (delta 0), pack-reused 4519
# Receiving objects: 100% (4520/4520), 188.12 MiB | 35.13 MiB/s, done.
# Resolving deltas: 100% (2873/2873), done.
# Already up-to-date.

# %%
os.chdir("..")
# !pip install https://github.com/fastai/fastai/archive/master.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://legacy.pypi.org/simple
# Collecting https://github.com/fastai/fastai/archive/master.zip
#   Downloading https://github.com/fastai/fastai/archive/master.zip (89.6MB)
#     100% |████████████████████████████████| 89.6MB 512kB/s
# Collecting awscli (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/26/a5/981fcedb0cba5cd167382878c92956229d14f0ac6846c71f2cd87906d474/awscli-1.15.10-py2.py3-none-any.whl (1.3MB)
#     100% |████████████████████████████████| 1.3MB 3.8MB/s
# Collecting bcolz (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/5c/4e/23942de9d5c0fb16f10335fa83e52b431bcb8c0d4a8419c9ac206268c279/bcolz-1.2.1.tar.gz (1.5MB)
#     100% |████████████████████████████████| 1.5MB 7.0MB/s
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (1.5.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (2018.4.16)
# Requirement already satisfied: cycler in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.10.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (4.3.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.2.3)
# Collecting feather-format (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/08/55/940b97cc6f19a19f5dab9efef2f68a0ce43a7632f858b272391f0b851a7e/feather-format-0.4.0.tar.gz
# Collecting graphviz (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/05/e4/8fcc76823534d47f079c0ff1b3d8b57784e8fba63ceb1ded32c9f4dd993c/graphviz-0.8.2-py2.py3-none-any.whl
# Requirement already satisfied: html5lib in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.9999999)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (4.6.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (5.5.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.2.0)
# Collecting ipywidgets (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/7d/24/fabc09ad81c6071159a4d12d5bfbddcbea69bd9e3b16c3250ef300c0285f/ipywidgets-7.2.1-py2.py3-none-any.whl (106kB)
#     100% |████████████████████████████████| 112kB 13.3MB/s
# Collecting isoweek (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/c2/d4/fe7e2637975c476734fcbf53776e650a29680194eb0dd21dbdc020ca92de/isoweek-1.3.3-py2.py3-none-any.whl
# Collecting jedi (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/e7/42/074192a165622e645ed4aeade63e76e56b3496a044569b3c6cae3a918352/jedi-0.12.0-py2.py3-none-any.whl (172kB)
#     100% |████████████████████████████████| 174kB 13.0MB/s
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (2.10)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (2.6.0)
# Collecting jupyter (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (5.2.3)
# Collecting jupyter-console (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/77/82/6469cd7fccf7958cbe5dce2e623f1e3c5e27f1bb1ad36d90519bc2d5d370/jupyter_console-5.2.0-py2.py3-none-any.whl
# Collecting jupyter_contrib_nbextensions (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/d2/f1/57cd4d05d7f070e662844a925d6f6d726ecaf93d8cc2d7b56a66c765fb42/jupyter_contrib_nbextensions-0.5.0-py2.py3-none-any.whl (20.9MB)
#     24% |███████▊
#     100% |████████████████████████████████| 20.9MB 2.4MB/s
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (4.4.0)
# Collecting kaggle-cli (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/67/61/710d02460bc4367ffd1f5e71cd9c031fb278f78aa0e8e32ca9dd99a2add8/kaggle-cli-0.12.13.tar.gz
# Requirement already satisfied: MarkupSafe in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (2.1.2)
# Requirement already satisfied: mistune in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.8.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (5.3.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (4.4.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (5.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (1.14.2)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.45.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (3.4.0.12)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.22.0)
# Collecting pandas_summary (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/3d/a7/0364272be0c6561c45d67edec8a7bf0532d56b830438168f9078f7720f63/pandas-summary-0.0.41.tar.gz
# Requirement already satisfied: pandocfilters in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (1.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (4.5.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.7.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (5.1.0)
# Collecting plotnine (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/3a/68/cf39dfde4e9fd886703621e3393cd8103cb48d5ecc95b8f048ec148e53a6/plotnine-0.3.0-py2.py3-none-any.whl (3.4MB)
#     100% |████████████████████████████████| 3.4MB 10.4MB/s
# Requirement already satisfied: prompt-toolkit in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (1.0.15)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.5.2)
# Requirement already satisfied: Pygments in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (2.1.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (2.2.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (2.5.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (2018.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (3.12)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (16.0.4)
# Collecting qtconsole (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/90/ff/047e0dca2627b162866920e7aa93f04523c0ae81e5c67060eec85701992d/qtconsole-4.3.1-py2.py3-none-any.whl (108kB)
#     100% |████████████████████████████████| 112kB 25.2MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.19.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.7.1)
# Requirement already satisfied: simplegeneric in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (1.11.0)
# Collecting sklearn_pandas (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/c5/9e/42d7bcddb09a3ff52d0c60c810ba5d0fded28abbe320c85bbf7368192956/sklearn_pandas-1.6.0-py2.py3-none-any.whl
# Requirement already satisfied: terminado in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.8.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.3.1)
# Collecting torchtext (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/78/90/474d5944d43001a6e72b9aaed5c3e4f77516fbef2317002da2096fd8b5ea/torchtext-0.2.3.tar.gz (42kB)
#     100% |████████████████████████████████| 51kB 17.1MB/s
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (4.5.3)
# Collecting tqdm (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/c2/d4/bf1d99216672eef50392c009a8d0f282c4b643e4f764c962ff7b611ebce4/tqdm-4.23.1-py2.py3-none-any.whl (42kB)
#     100% |████████████████████████████████| 51kB 19.2MB/s
# Requirement already satisfied: traitlets in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (4.3.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.1.7)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from fastai==0.6) (0.5.1)
# Collecting widgetsnbextension (from fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/ff/fa/64acc09fc845a6b2dc0724d6f3f81e829b778ed5e9a7559567b4f19a3f4b/widgetsnbextension-3.2.1-py2.py3-none-any.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 8.5MB/s
# Collecting botocore==1.10.10 (from awscli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/77/c9/a40ebce24bbab4c7986fccdac9dade097385ad2feae73dcc47d31a1b4dc8/botocore-1.10.10-py2.py3-none-any.whl (4.2MB)
#     100% |████████████████████████████████| 4.2MB 10.1MB/s
# Requirement already satisfied: rsa<=3.5.0,>=3.1.2 in /usr/local/lib/python3.6/dist-packages (from awscli->fastai==0.6) (3.4.2)
# Collecting colorama<=0.3.7,>=0.2.5 (from awscli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/b7/8e/ddb32ddaabd431813e180ca224e844bab8ad42fbb47ee07553f0ec44cd86/colorama-0.3.7-py2.py3-none-any.whl
# Collecting docutils>=0.10 (from awscli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/36/fa/08e9e6e0e3cbd1d362c3bbee8d01d0aedb2155c4ac112b19ef3cae8eed8d/docutils-0.14-py3-none-any.whl (543kB)
#     100% |████████████████████████████████| 552kB 24.1MB/s
# Collecting s3transfer<0.2.0,>=0.1.12 (from awscli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/d7/14/2a0004d487464d120c9fb85313a75cd3d71a7506955be458eebfe19a6b1d/s3transfer-0.1.13-py2.py3-none-any.whl (59kB)
#     100% |████████████████████████████████| 61kB 16.4MB/s
# Collecting pyarrow>=0.4.0 (from feather-format->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/fe/27/576e6c979bfa5f63070f809c930aa85d6198b91d17a64866234597ba861f/pyarrow-0.9.0-cp36-cp36m-manylinux1_x86_64.whl (13.7MB)
#     100% |████████████████████████████████| 13.7MB 3.1MB/s
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.6) (39.0.1)
# Collecting parso>=0.2.0 (from jedi->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/63/69/0c383765d192006330bfaae27a2c5d0933fb4760c5aacd933b8b19391693/parso-0.2.0-py2.py3-none-any.whl (90kB)
#     100% |████████████████████████████████| 92kB 13.7MB/s
# Collecting jupyter-nbextensions-configurator>=0.4.0 (from jupyter_contrib_nbextensions->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/d1/d8/6bf103e0eafd17caef39c37ff70b8d61bfb21cc8cd91c81ba51755421a34/jupyter_nbextensions_configurator-0.4.0-py2.py3-none-any.whl (466kB)
#     100% |████████████████████████████████| 471kB 26.2MB/s
# Collecting jupyter-contrib-core>=0.3.3 (from jupyter_contrib_nbextensions->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/e6/8f/04a752a8b66a66e7092c035e5d87d2502ac7ec07f9fb6059059b6c0dc272/jupyter_contrib_core-0.3.3-py2.py3-none-any.whl
# Collecting jupyter-highlight-selected-word>=0.1.1 (from jupyter_contrib_nbextensions->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/50/d7/19ab7cfd60bf268d2abbacc52d4295a40f52d74dfc0d938e4761ee5e598b/jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl
# Collecting lxml (from jupyter_contrib_nbextensions->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/a7/b9/ccf46cea0f698b40bca2a9c1a44039c336fe1988b82de4f7353be7a8396a/lxml-4.2.1-cp36-cp36m-manylinux1_x86_64.whl (5.6MB)
#     100% |████████████████████████████████| 5.7MB 11.6MB/s
# Collecting jupyter-latex-envs>=1.3.8 (from jupyter_contrib_nbextensions->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/98/db/ef83fb7a8dd71a1c38d8cc5484bb5226dcd8dd996483d6ad3d944670c57b/jupyter_latex_envs-1.4.4.tar.gz (855kB)
#     100% |████████████████████████████████| 860kB 20.5MB/s
# Collecting cliff<2.9,>=2.8.0 (from kaggle-cli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/ee/e8/140ad9b5826920a8b85c187095e7725b87b913fc40243aa66dd04e9d82d6/cliff-2.8.1.tar.gz (73kB)
#     100% |████████████████████████████████| 81kB 23.0MB/s
# Collecting MechanicalSoup<0.9,>=0.7.0 (from kaggle-cli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/5c/2e/f63ed26b51e36efa4cc22cad18187fcb0a253f756d548c96bb931f13de98/MechanicalSoup-0.8.0-py2.py3-none-any.whl
# Collecting cssselect<1.1,>=1.0.1 (from kaggle-cli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/7b/44/25b7283e50585f0b4156960691d951b05d061abf4a714078393e51929b30/cssselect-1.0.3-py2.py3-none-any.whl
# Collecting configparser (from kaggle-cli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/7c/69/c2ce7e91c89dc073eb1aa74c0621c3eefbffe8216b3f9af9d3885265c01c/configparser-3.5.0.tar.gz
# Collecting progressbar2<3.35,>=3.34.3 (from kaggle-cli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/87/31/b984e17bcc7491c1baeda3906fe3abc14cb5cd5dbd046ab46d9fc7a2edfd/progressbar2-3.34.3-py2.py3-none-any.whl
# Requirement already satisfied: beautifulsoup4<4.7,>=4.6.0 in /usr/local/lib/python3.6/dist-packages (from kaggle-cli->fastai==0.6) (4.6.0)
# Collecting mizani>=0.4.1 (from plotnine->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/52/01/8a3b4c6e45749674a1e5241174b4b63cd6435125e124bec275f3e02c96ac/mizani-0.4.6-py2.py3-none-any.whl (65kB)
#     100% |████████████████████████████████| 71kB 20.3MB/s
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.6) (0.5.0)
# Requirement already satisfied: statsmodels>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.6) (0.8.0)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.6/dist-packages (from sklearn_pandas->fastai==0.6) (0.19.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext->fastai==0.6) (2.18.4)
# Collecting jmespath<1.0.0,>=0.7.1 (from botocore==1.10.10->awscli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<=3.5.0,>=3.1.2->awscli->fastai==0.6) (0.4.2)
# Collecting pbr!=2.1.0,>=2.0.0 (from cliff<2.9,>=2.8.0->kaggle-cli->fastai==0.6)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/e1/ba/f95e3ec83f93919b1437028e989cf3fa5ff4f5cae4a1f62255f71deddb5b/pbr-4.0.2-py2.py3-none-any.whl (98kB)
#     100% |████████████████████████████████| 102kB 23.1MB/s
# Collecting cmd2>=0.6.7 (from cliff<2.9,>=2.8.0->kaggle-cli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/ee/02/faa35704449a68f18db39ee9a047e32c8b569e672daadfef3501259fe6bb/cmd2-0.8.5-py2.py3-none-any.whl (51kB)
#     100% |████████████████████████████████| 61kB 18.1MB/s
# Collecting PrettyTable<0.8,>=0.7.1 (from cliff<2.9,>=2.8.0->kaggle-cli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/ef/30/4b0746848746ed5941f052479e7c23d2b56d174b82f4fd34a25e389831f5/prettytable-0.7.2.tar.bz2
# Collecting stevedore>=1.20.0 (from cliff<2.9,>=2.8.0->kaggle-cli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/17/6b/3b7d6d08b2ab3e5ef09e01c9f7b3b590ee135f289bb94553419e40922c25/stevedore-1.28.0-py2.py3-none-any.whl
# Collecting python-utils>=2.1.0 (from progressbar2<3.35,>=3.34.3->kaggle-cli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/eb/a0/19119d8b7c05be49baf6c593f11c432d571b70d805f2fe94c0585e55e4c8/python_utils-2.3.0-py2.py3-none-any.whl
# Collecting palettable (from mizani>=0.4.1->plotnine->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/ba/cc/54b3ebfc5d3369e242c600ed49dcdcd3f53a9ac46b082da274386859c821/palettable-3.1.0-py2.py3-none-any.whl (78kB)
#     100% |████████████████████████████████| 81kB 21.6MB/s
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.6) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.6) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.6) (3.0.4)
# Collecting pyperclip (from cmd2>=0.6.7->cliff<2.9,>=2.8.0->kaggle-cli->fastai==0.6)
#   Downloading https://files.pythonhosted.org/packages/5b/06/86e3c6a55cacef0e4ec7c25379ff7fcd1a88fd939ecefd442b535c792fa4/pyperclip-1.6.0.tar.gz
# Building wheels for collected packages: fastai, bcolz, feather-format, kaggle-cli, pandas-summary, torchtext, jupyter-latex-envs, cliff, configparser, PrettyTable, pyperclip
# done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qle1bhf5/wheels/64/3d/9f/d12a217aa2531321c5b9ae96288fcae2687d3b744376e8f94f
# \
# done
#   Stored in directory: /content/.cache/pip/wheels/9f/78/26/fb8c0acb91a100dc8914bf236c4eaa4b207cb876893c40b745
# done
#   Stored in directory: /content/.cache/pip/wheels/85/7d/12/2dfa5c0195f921ac935f5e8f27deada74972edc0ae9988a9c1
# done
#   Stored in directory: /content/.cache/pip/wheels/d5/bb/10/c1dd1b08c7433c943cb55c46367ae3f891415e8a37300ff8a7
# done
#   Stored in directory: /content/.cache/pip/wheels/86/a9/6b/36b727a9ec687dac08bd3d0501cddd7b1a223943513eb04a03
# done
#   Stored in directory: /content/.cache/pip/wheels/42/a6/f4/b267328bde6bb680094a0c173e8e5627ccc99543abded97204
# done
#   Stored in directory: /content/.cache/pip/wheels/65/c1/0f/b90b6d7032c79ee40181fdadb72b2ef9a186f02269d6c52f02
# done
#   Stored in directory: /content/.cache/pip/wheels/50/00/6d/d4aeb5ccdd47dd76800592b26f943e4959bc705b2d4e6e54e1
# done
#   Stored in directory: /content/.cache/pip/wheels/a3/61/79/424ef897a2f3b14684a7de5d89e8600b460b89663e6ce9d17c
# done
#   Stored in directory: /content/.cache/pip/wheels/80/34/1c/3967380d9676d162cb59513bd9dc862d0584e045a162095606
# done
#   Stored in directory: /content/.cache/pip/wheels/a7/68/ef/ab1ef01625334f10a979e9fe5ef79e1c4fd4cdf4b710a0067b
# Successfully built fastai bcolz feather-format kaggle-cli pandas-summary torchtext jupyter-latex-envs cliff configparser PrettyTable pyperclip
# pysnmp 4.3.2 requires pysmi, which is not installed.
# kaggle-cli 0.12.13 has requirement lxml<4.1,>=4.0.0, but you'll have lxml 4.2.1 which is incompatible.
# plotnine 0.3.0 has requirement scipy>=1.0.0, but you'll have scipy 0.19.1 which is incompatible.
# Installing collected packages: docutils, jmespath, botocore, colorama, s3transfer, awscli, bcolz, pyarrow, feather-format, graphviz, widgetsnbextension, ipywidgets, isoweek, parso, jedi, qtconsole, jupyter-console, jupyter, jupyter-contrib-core, jupyter-nbextensions-configurator, jupyter-highlight-selected-word, lxml, jupyter-latex-envs, jupyter-contrib-nbextensions, pbr, pyperclip, cmd2, PrettyTable, stevedore, cliff, MechanicalSoup, cssselect, configparser, python-utils, progressbar2, kaggle-cli, pandas-summary, palettable, mizani, plotnine, sklearn-pandas, tqdm, torchtext, fastai
# Successfully installed MechanicalSoup-0.8.0 PrettyTable-0.7.2 awscli-1.15.10 bcolz-1.2.1 botocore-1.10.10 cliff-2.8.1 cmd2-0.8.5 colorama-0.3.7 configparser-3.5.0 cssselect-1.0.3 docutils-0.14 fastai-0.6 feather-format-0.4.0 graphviz-0.8.2 ipywidgets-7.2.1 isoweek-1.3.3 jedi-0.12.0 jmespath-0.9.3 jupyter-1.0.0 jupyter-console-5.2.0 jupyter-contrib-core-0.3.3 jupyter-contrib-nbextensions-0.5.0 jupyter-highlight-selected-word-0.2.0 jupyter-latex-envs-1.4.4 jupyter-nbextensions-configurator-0.4.0 kaggle-cli-0.12.13 lxml-4.2.1 mizani-0.4.6 palettable-3.1.0 pandas-summary-0.0.41 parso-0.2.0 pbr-4.0.2 plotnine-0.3.0 progressbar2-3.34.3 pyarrow-0.9.0 pyperclip-1.6.0 python-utils-2.3.0 qtconsole-4.3.1 s3transfer-0.1.13 sklearn-pandas-1.6.0 stevedore-1.28.0 torchtext-0.2.3 tqdm-4.23.1 widgetsnbextension-3.2.1

# %%
# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision
import torch
# Out:
# pysnmp 4.3.2 requires pysmi, which is not installed.

# %%
# !pip install ipywidgets==6.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://legacy.pypi.org/simple
# Collecting ipywidgets==6.0.0
#   Downloading https://files.pythonhosted.org/packages/3b/52/3706ce0e828d65b29f00e9c8a340317fdb94d125afe322f807e98579bcbe/ipywidgets-6.0.0-py2.py3-none-any.whl (46kB)
#     100% |████████████████████████████████| 51kB 2.1MB/s
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0) (5.5.0)
# Collecting widgetsnbextension~=2.0.0 (from ipywidgets==6.0.0)
#   Downloading https://files.pythonhosted.org/packages/50/b3/7c86d28eab49808e82f26ba9882ff31170e25b584f28edec80d6fdfc270c/widgetsnbextension-2.0.1-py2.py3-none-any.whl (1.1MB)
#     100% |████████████████████████████████| 1.1MB 7.1MB/s
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0) (4.6.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0) (4.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets==6.0.0) (4.3.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (2.1.3)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (1.0.15)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (4.5.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (39.0.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (4.3.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipywidgets==6.0.0) (0.7.4)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (5.2.2)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets==6.0.0) (4.5.3)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets==6.0.0) (5.2.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets==6.0.0) (2.6.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets==6.0.0) (0.2.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets==6.0.0) (4.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.1->ipywidgets==6.0.0) (1.11.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets==6.0.0) (0.1.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0->ipywidgets==6.0.0) (0.5.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (2.10)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (5.3.1)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (0.8.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets==6.0.0) (16.0.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets==6.0.0) (2.5.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (0.2.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (0.3.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (1.4.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (1.5.0)
# Requirement already satisfied: mistune>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (0.8.3)
# Requirement already satisfied: html5lib!=0.9999,!=0.99999,<0.99999999,>=0.999 in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=2.0.0->ipywidgets==6.0.0) (0.9999999)
# pysnmp 4.3.2 requires pysmi, which is not installed.
# plotnine 0.3.0 has requirement scipy>=1.0.0, but you'll have scipy 0.19.1 which is incompatible.
# kaggle-cli 0.12.13 has requirement lxml<4.1,>=4.0.0, but you'll have lxml 4.2.1 which is incompatible.
# Installing collected packages: widgetsnbextension, ipywidgets
#   Found existing installation: widgetsnbextension 3.2.1
#     Uninstalling widgetsnbextension-3.2.1:
#       Successfully uninstalled widgetsnbextension-3.2.1
#   Found existing installation: ipywidgets 7.2.1
#     Uninstalling ipywidgets-7.2.1:
#       Successfully uninstalled ipywidgets-7.2.1
# Successfully installed ipywidgets-6.0.0 widgetsnbextension-2.0.1

# %%
#Now go to your Google Drive and open the notebook
#Make sure you have runtime type for this as well as the notebook in google drive to GPU

# %% [markdown]
# # PyDrive

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

from pathlib import Path
import os

def download_and_save(file_name, file_id):
  downloaded = drive.CreateFile({'id': file_id})
  # fetch file
  downloaded.FetchContent()
  # write file
  with open(file_name,'wb') as f:
       f.write(downloaded.content.read())
      
  print(f'Saved {file_name}')
  
FILE_NAME, FILE_ID = ['file_name', 'file_id']
# Out:
# pysnmp 4.3.2 requires pysmi, which is not installed.
# plotnine 0.3.0 has requirement scipy>=1.0.0, but you'll have scipy 0.19.1 which is incompatible.
# kaggle-cli 0.12.13 has requirement lxml<4.1,>=4.0.0, but you'll have lxml 4.2.1 which is incompatible.

# %% [markdown]
# # Get dataset(s)

# %%
from pathlib import Path

dataset_path = Path.home() / 'data/old_polish_cars'; dataset_path
# !mkdir -p $dataset_path
# !ls -la $dataset_path
# Out:
# total 4987732
# drwxr-xr-x  4 root      root            4096 Apr 28 20:06 .
# drwxr-xr-x  3 root      root            4096 Apr 28 16:32 ..
# drwxr-xr-x 12 349452163 349400513       4096 Apr 28 19:09 old_polish_cars_v4_photos
# -rw-r--r--  1 root      root      2541949892 Apr 28 20:06 old_polish_cars_v4_photos-20180428.tgz
# drwxr-xr-x  7 349452163 349400513       4096 Apr  9 21:23 old_polish_cars_v5_photos-split
# -rw-r--r--  1 root      root      2565459704 Apr 28 20:14 old_polish_cars_v5_photos-split-2017-11-15.tgz

# %% [markdown]
# ## get old_polish_cars_v5-split dataset

# %%
old_polish_cars_v5 = {FILE_NAME: 'old_polish_cars_v5_photos-split-2017-11-15.tgz', FILE_ID: '1_JgAlUNebGH3JUioSPWW-GV_eL4K1txM'}
old_polish_cars_v5_path = dataset_path / old_polish_cars_v5[FILE_NAME]
download_and_save(old_polish_cars_v5_path, old_polish_cars_v5[FILE_ID])
# Out:
# Saved /content/data/old_polish_cars/old_polish_cars_v5_photos-split-2017-11-15.tgz

# %%
# unpack
# !tar -xf $old_polish_cars_v5_path -C $dataset_path

# %% [markdown]
# ## get old_polish_cars_v4 dataset

# %%
old_polish_cars_v4 = {FILE_NAME: 'old_polish_cars_v4_photos-20180428.tgz', FILE_ID: '1uqJz7Sb-PawB9hjd9R4X9x4XdRUHacto'}
old_polish_cars_v4_path = dataset_path / old_polish_cars_v4[FILE_NAME]

download_and_save(old_polish_cars_v4_path, old_polish_cars_v4[FILE_ID])
# Out:
# Saved /content/data/old_polish_cars/old_polish_cars_v4_photos-20180428.tgz

# %%
# unpack

# !tar -xf $old_polish_cars_v4_path -C $dataset_path

# %% [markdown]
# # Get plots_wcz.py

# %%
download_and_save(Path.home() / 'plots_wcz.py', '1CIc_hlYNzypzZFnFi4iQXtoyLj1C7-vS')
# !cp ~/plots_wcz.py /usr/local/lib/python3.6/dist-packages/fastai
# Out:
# Saved /content/plots_wcz.py

# %% [markdown]
# # Monitoring VM

# %%
# !ls -a
# Out:
# .  ..  .cache  .config	data  datalab  .forever  .ipython  .local  .rnd

# %%
who
# Out:
# GoogleCredentials	 accelerator	 auth	 creds	 get_abbr_impl	 get_abi_tag	 get_impl_ver	 getpass	 os
# path	 platform	 torch	 vcode

# %%
# !uptime
# Out:
#  20:14:56 up  4:06,  4 users,  load average: 1.62, 0.61, 0.31

# %%
cd fastai
# Out:
# /content/fastai

# %%
# !/opt/bin/nvidia-smi
# Out:
# Thu Apr 12 15:26:18 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.111                Driver Version: 384.111                   |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   74C    P0   121W / 149W |   3719MiB / 11439MiB |     29%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
for i in range(3):
  # !top -n 1
# Out:
# =top - 15:27:24 up  1:39,  0 users,  load average: 6.99, 7.19, 6.69
# Tasks:  11 total,   1 running,  10 sleeping,   0 stopped,   0 zombie
# %Cpu(s): 40.0 us,  3.9 sy,  0.0 ni, 55.0 id,  0.9 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13341832 total,   167480 free,  4449016 used,  8725336 buff/cache
# KiB Swap:        0 total,        0 free,        0 used.  8407400 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#  1931 root      20   0 41.649g 3.945g 363404 S 166.7 31.0  64:32.08 python3
#    81 root      20   0  733196  69756  22912 S   6.7  0.5   0:27.62 node
#    91 root      20   0  199716  72256  11960 S   6.7  0.5   0:18.98 jupyter-no+
#  1737 root      20   0 1855576 227780 101832 S   6.7  1.7   0:04.07 python3
#     1 root      20   0   39144   6400   5024 S   0.0  0.0   0:00.09 run.sh
#    71 root      20   0  678296  40440  21708 S   0.0  0.3   0:03.39 node
#   752 root      20   0  127780   6512   4304 S   0.0  0.0   0:00.14 dirmngr
#  1179 root      20   0  184200  35440   8640 S   0.0  0.3   0:02.63 google-dri+
#  1721 root      20   0  677288 127112  39308 S   0.0  1.0   0:01.95 python3
#  2172 root      20   0   33964   4840   3736 S   0.0  0.0   0:01.28 sh
#  2173 root      20   0   65360   6856   5100 R   0.0  0.1   0:00.00 top
# >
# =top - 15:27:30 up  1:39,  0 users,  load average: 7.30, 7.25, 6.72
# Tasks:  11 total,   1 running,  10 sleeping,   0 stopped,   0 zombie
# %Cpu(s): 40.1 us,  3.9 sy,  0.0 ni, 55.0 id,  0.9 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13341832 total,   167464 free,  4448936 used,  8725432 buff/cache
# KiB Swap:        0 total,        0 free,        0 used.  8407476 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#  1931 root      20   0 41.649g 3.945g 363404 S 193.3 31.0  64:42.02 python3
#    81 root      20   0  733196  69732  22912 S  13.3  0.5   0:27.68 node
#    91 root      20   0  199716  72256  11960 S   6.7  0.5   0:19.02 jupyter-no+
#     1 root      20   0   39144   6400   5024 S   0.0  0.0   0:00.09 run.sh
#    71 root      20   0  678296  40440  21708 S   0.0  0.3   0:03.39 node
#   752 root      20   0  127780   6512   4304 S   0.0  0.0   0:00.14 dirmngr
#  1179 root      20   0  184200  35440   8640 S   0.0  0.3   0:02.63 google-dri+
#  1721 root      20   0  677288 127112  39308 S   0.0  1.0   0:01.95 python3
#  1737 root      20   0 1855576 227780 101832 S   0.0  1.7   0:04.09 python3
#  2174 root      20   0   33964   4680   3564 S   0.0  0.0   0:01.27 sh
#  2175 root      20   0   65360   6892   5140 R   0.0  0.1   0:00.00 top
# >
# =top - 15:27:35 up  1:39,  0 users,  load average: 7.27, 7.25, 6.72
# Tasks:  11 total,   1 running,  10 sleeping,   0 stopped,   0 zombie
# %Cpu(s): 40.1 us,  3.9 sy,  0.0 ni, 54.9 id,  0.9 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13341832 total,   166764 free,  4449572 used,  8725496 buff/cache
# KiB Swap:        0 total,        0 free,        0 used.  8406840 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#  1931 root      20   0 41.649g 3.945g 363404 S 170.6 31.0  64:50.08 python3
#    81 root      20   0  733196  69928  22912 S   5.9  0.5   0:27.73 node
#     1 root      20   0   39144   6400   5024 S   0.0  0.0   0:00.09 run.sh
#    71 root      20   0  678296  40440  21708 S   0.0  0.3   0:03.40 node
#    91 root      20   0  199716  72256  11960 S   0.0  0.5   0:19.04 jupyter-no+
#   752 root      20   0  127780   6512   4304 S   0.0  0.0   0:00.14 dirmngr
#  1179 root      20   0  184200  35440   8640 S   0.0  0.3   0:02.63 google-dri+
#  1721 root      20   0  677288 127112  39308 S   0.0  1.0   0:01.95 python3
#  1737 root      20   0 1855576 227780 101832 S   0.0  1.7   0:04.11 python3
#  2176 root      20   0   33964   4744   3636 S   0.0  0.0   0:01.29 sh
#  2177 root      20   0   65356   6920   5168 R   0.0  0.1   0:00.00 top
# >
# =top - 15:27:39 up  1:40,  0 users,  load average: 7.27, 7.25, 6.72
# Tasks:  11 total,   2 running,   9 sleeping,   0 stopped,   0 zombie
# %Cpu(s): 40.1 us,  3.9 sy,  0.0 ni, 54.9 id,  0.9 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13341832 total,   168012 free,  4448136 used,  8725684 buff/cache
# KiB Swap:        0 total,        0 free,        0 used.  8408280 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#  1931 root      20   0 41.649g 3.945g 363404 R 186.7 31.0  64:56.31 python3
#     1 root      20   0   39144   6400   5024 S   0.0  0.0   0:00.09 run.sh
#    71 root      20   0  678296  40440  21708 S   0.0  0.3   0:03.40 node
#    81 root      20   0  733196  70284  22912 S   0.0  0.5   0:27.75 node
#    91 root      20   0  199716  72256  11960 S   0.0  0.5   0:19.06 jupyter-no+
#   752 root      20   0  127780   6512   4304 S   0.0  0.0   0:00.14 dirmngr
#  1179 root      20   0  184200  35440   8640 S   0.0  0.3   0:02.63 google-dri+
#  1721 root      20   0  677288 127112  39308 S   0.0  1.0   0:01.95 python3
#  1737 root      20   0 1855576 227780 101832 S   0.0  1.7   0:04.13 python3
#  2178 root      20   0   33960   4988   3884 S   0.0  0.0   0:01.27 sh
#  2179 root      20   0   65360   6844   5092 R   0.0  0.1   0:00.00 top
# >
# =top - 15:27:41 up  1:40,  0 users,  load average: 6.93, 7.18, 6.70
# Tasks:  11 total,   1 running,  10 sleeping,   0 stopped,   0 zombie
# %Cpu(s): 40.2 us,  3.9 sy,  0.0 ni, 54.9 id,  0.9 wa,  0.0 hi,  0.1 si,  0.0 st
# KiB Mem : 13341832 total,   167372 free,  4448708 used,  8725752 buff/cache
# KiB Swap:        0 total,        0 free,        0 used.  8407708 avail Mem
#
#   PID USER      PR  NI    VIRT    RES    SHR S  %CPU %MEM     TIME+ COMMAND
#  1931 root      20   0 41.649g 3.945g 363404 S  93.3 31.0  64:58.76 python3
#     1 root      20   0   39144   6400   5024 S   0.0  0.0   0:00.09 run.sh
#    71 root      20   0  678296  40440  21708 S   0.0  0.3   0:03.40 node
#    81 root      20   0  733196  70460  22912 S   0.0  0.5   0:27.78 node
#    91 root      20   0  199716  72256  11960 S   0.0  0.5   0:19.08 jupyter-no+
#   752 root      20   0  127780   6512   4304 S   0.0  0.0   0:00.14 dirmngr
#  1179 root      20   0  184200  35440   8640 S   0.0  0.3   0:02.63 google-dri+
#  1721 root      20   0  677288 127112  39308 S   0.0  1.0   0:01.95 python3
#  1737 root      20   0 1855576 227780 101832 S   0.0  1.7   0:04.15 python3
#  2180 root      20   0   33964   5076   3984 S   0.0  0.0   0:01.28 sh
#  2181 root      20   0   65356   6896   5140 R   0.0  0.1   0:00.00 top
# >

# %%
# !top -h
# Out:
#   procps-ng 3.3.12
# Usage:
#   top -hv | -bcHiOSs -d secs -n max -u|U user -p pid(s) -o field -w [cols]

# %%
import os
import psutil

def print_memsize():
  process = psutil.Process(os.getpid())
  print(f'{process.memory_info().rss / 1024**3:.5} GB')
  
print_memsize()
# Out:
# 2.2789 GB

# %%
print_memsize()
# Out:
# 0.12072 GB
